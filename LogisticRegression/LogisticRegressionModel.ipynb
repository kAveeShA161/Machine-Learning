# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('D:\Machine Learning\LogisticRegression\Book3.csv')

# %%
data
# Out:
#     Age  Job
# 0    16    0
# 1    24    0
# 2    31    1
# 3    29    0
# 4    40    1
# 5    33    0
# 6    18    0
# 7    36    1
# 8    15    0
# 9    37    1
# 10   19    0
# 11   21    0
# 12   29    1
# 13   31    1
# 14   23    1
# 15   20    0
# 16   34    1
# 17   22    0
# 18   32    1

# %%
plt.scatter(data.Age,data.Job)

# %%
x = data[["Age"]]
x
# Out:
#     Age
# 0    16
# 1    24
# 2    31
# 3    29
# 4    40
# 5    33
# 6    18
# 7    36
# 8    15
# 9    37
# 10   19
# 11   21
# 12   29
# 13   31
# 14   23
# 15   20
# 16   34
# 17   22
# 18   32

# %%
y = data["Job"]

# %%
y
# Out:
# 0     0
# 1     0
# 2     1
# 3     0
# 4     1
# 5     0
# 6     0
# 7     1
# 8     0
# 9     1
# 10    0
# 11    0
# 12    1
# 13    1
# 14    1
# 15    0
# 16    1
# 17    0
# 18    1
# Name: Job, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %%
x_train
# Out:
#     Age
# 12   29
# 1    24
# 18   32
# 14   23
# 0    16
# 16   34
# 5    33
# 15   20
# 6    18
# 3    29
# 4    40
# 10   19
# 7    36
# 17   22
# 13   31

# %%
len(x_train)
# Out:
# 15

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()

# %%
model.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
model.predict(x_test)
# Out:
# array([1, 0, 0, 1])

# %%
x_test
# Out:
#     Age
# 2    31
# 8    15
# 11   21
# 9    37

# %%
y_test
# Out:
# 2     1
# 8     0
# 11    0
# 9     1
# Name: Job, dtype: int64

# %%
model.score(x_test, y_test)
# Out:
# 1.0

# %%
age = [[24]]
model.predict(age)
# Out:
# C:\Users\kavee\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([0])

# %%
ages = np.array([[43], [21], [25], [42]])
model.predict(ages)
# Out:
# C:\Users\kavee\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([1, 0, 0, 1])
